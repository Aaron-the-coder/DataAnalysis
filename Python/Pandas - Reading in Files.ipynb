# %% [markdown]
# # Reading In Files

# %%
import pandas as pd
pd.read_csv(r"F:\Files\sunflowerLog\driver.20230519-213349.log",sep="\t")
# Out:
#    2023-05-19 21:33:49.880  - Info  -  \
# 0  2023-05-19 21:33:49.985  * Error *
# 1  2023-05-19 21:33:51.296  * Error *
#
#                           version:10.3.0.27372
# 0  [print] DeletePort error:1722 name:OrayPort
# 1    [print] DeletePort error:50 name:OrayPort

# %%
pd.read_csv(r'E:/DataAnalysis/Python/Pandas/Sales.csv')
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
pd.read_csv(r'E:/DataAnalysis/Python/Pandas/Sales.csv', header=None, names=['cost', 'revenue'])
# Out:
# C:\Users\Dale Smith\AppData\Local\Temp\ipykernel_2360\3332517887.py:1: DtypeWarning: Columns (1,3,4,12,13,14,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(r'E:/DataAnalysis/Python/Pandas/Sales.csv', header=None, names=['cost', 'revenue'])
#                                                                                                                                                                                                        cost  \
# Date       Day Month    Year Customer_Age Age_Group      Customer_Gender Country        State            Product_Category Sub_Category Product             Order_Quantity Unit_Cost Unit_Price Profit  Cost
# 2013-11-26 26  November 2013 19           Youth (<25)    M               Canada         British Columbia Accessories      Bike Racks   Hitch Rack - 4-Bike 8              45        120        590      360
# ...

# %%
pd.read_table(r"E:\DataAnalysis\Python\Pandas\Sales.txt")
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
df = pd.read_json(r"E:\DataAnalysis\Python\Pandas\Sales.json")
df
# Out:
#                                  outputType  \
# 0  {'type': 'INSTANT_RUN_MERGED_MANIFESTS'}
#
#                                              apkInfo                 path  \
# 0  {'type': 'MAIN', 'splits': [], 'versionCode': ...  AndroidManifest.xml
#
#                                           properties
# 0  {'packageId': 'com.lqb.dale.demos', 'split': '...

# %%
df = pd.read_excel(r"E:\DataAnalysis\Python\Pandas\a.xlsx", sheet_name='SC分册', header=None)
df
# Out:
# D:\installFolder\Anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
#        0    1                                                  2  \
# 0     序号   分类                                                 题目
# 1      1  NaN  Like ants, termites have an elaborate social s...
# 2      2  NaN  Some 200 world-famous physicists recently atte...
# 3      3  NaN  Global warming is said to be responsible for e...
# 4      4  NaN  Some bat caves, like honeybee hives, have resi...
# 5      5  NaN  The voluminous personal papers of Thomas Alva ...
# 6      6  NaN  Hundreds of species of fish generate and disch...
# 7      7  NaN  Native to South America, when peanuts were int...
# 8      8  NaN  It stood twelve feet tall,weighed nine thousan...
# 9      9  NaN  Delighted by the reported earnings for the fir...
# 10    10  NaN  The rising of costs of data-processing operati...
# ...

# %% [markdown]
# pd.set_option('display.max.rows', 114)
# pd.set_option('display.max.columns', 28)

# %%
df = pd.read_excel(r"E:\DataAnalysis\Python\Pandas\b.xlsx")
df
# Out:
#    iso_code continent     location       date  population  total_cases  \
# 0       AFG      Asia  Afghanistan 2020-01-03    41128772          NaN
# 1       AFG      Asia  Afghanistan 2020-01-04    41128772          NaN
# 2       AFG      Asia  Afghanistan 2020-01-05    41128772          NaN
# 3       AFG      Asia  Afghanistan 2020-01-06    41128772          NaN
# 4       AFG      Asia  Afghanistan 2020-01-07    41128772          NaN
# 5       AFG      Asia  Afghanistan 2020-01-08    41128772          NaN
# 6       AFG      Asia  Afghanistan 2020-01-09    41128772          NaN
# 7       AFG      Asia  Afghanistan 2020-01-10    41128772          NaN
# 8       AFG      Asia  Afghanistan 2020-01-11    41128772          NaN
# 9       AFG      Asia  Afghanistan 2020-01-12    41128772          NaN
# 10      AFG      Asia  Afghanistan 2020-01-13    41128772          NaN
# 11      AFG      Asia  Afghanistan 2020-01-14    41128772          NaN
# ...

# %%
pd.set_option('display.max.rows', 114) 
pd.set_option('display.max.columns', 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 26 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            49 non-null     object
#  1   continent                           49 non-null     object
#  2   location                            49 non-null     object
#  3   date                                49 non-null     datetime64[ns]
#  4   population                          49 non-null     int64
#  5   total_cases                         0 non-null      float64
#  6   new_cases                           49 non-null     int64
#  7   new_cases_smoothed                  44 non-null     float64
#  8   total_deaths                        0 non-null      float64
#  9   new_deaths                          49 non-null     int64
#  10  new_deaths_smoothed                 44 non-null     float64
# ...

# %%
df.shape
# Out:
# (49, 26)

# %%
df.head(10)
# Out:
#   iso_code continent     location       date  population  total_cases  \
# 0      AFG      Asia  Afghanistan 2020-01-03    41128772          NaN
# 1      AFG      Asia  Afghanistan 2020-01-04    41128772          NaN
# 2      AFG      Asia  Afghanistan 2020-01-05    41128772          NaN
# 3      AFG      Asia  Afghanistan 2020-01-06    41128772          NaN
# 4      AFG      Asia  Afghanistan 2020-01-07    41128772          NaN
# 5      AFG      Asia  Afghanistan 2020-01-08    41128772          NaN
# 6      AFG      Asia  Afghanistan 2020-01-09    41128772          NaN
# 7      AFG      Asia  Afghanistan 2020-01-10    41128772          NaN
# 8      AFG      Asia  Afghanistan 2020-01-11    41128772          NaN
# 9      AFG      Asia  Afghanistan 2020-01-12    41128772          NaN
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0          0                 NaN           NaN           0
# 1          0                 NaN           NaN           0
# ...

# %%
df.tail(10)
# Out:
#    iso_code continent     location       date  population  total_cases  \
# 39      AFG      Asia  Afghanistan 2020-02-11    41128772          NaN
# 40      AFG      Asia  Afghanistan 2020-02-12    41128772          NaN
# 41      AFG      Asia  Afghanistan 2020-02-13    41128772          NaN
# 42      AFG      Asia  Afghanistan 2020-02-14    41128772          NaN
# 43      AFG      Asia  Afghanistan 2020-02-15    41128772          NaN
# 44      AFG      Asia  Afghanistan 2020-02-16    41128772          NaN
# 45      AFG      Asia  Afghanistan 2020-02-17    41128772          NaN
# 46      AFG      Asia  Afghanistan 2020-02-18    41128772          NaN
# 47      AFG      Asia  Afghanistan 2020-02-19    41128772          NaN
# 48      AFG      Asia  Afghanistan 2020-02-20    41128772          NaN
#
#     new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 39          0                 0.0           NaN           0
# 40          0                 0.0           NaN           0
# ...

# %%
df[47]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\installFolder\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File D:\installFolder\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\installFolder\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 47
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.loc[8]
# Out:
# iso_code                                              AFG
# continent                                            Asia
# location                                      Afghanistan
# date                                  2020-01-11 00:00:00
# population                                       41128772
# total_cases                                           NaN
# new_cases                                               0
# new_cases_smoothed                                    0.0
# total_deaths                                          NaN
# new_deaths                                              0
# new_deaths_smoothed                                   0.0
# total_cases_per_million                               NaN
# new_cases_per_million                                   0
# new_cases_smoothed_per_million                        0.0
# total_deaths_per_million                              NaN
# new_deaths_per_million                                  0
# ...

# %%
import datetime as dt

# %%
df.loc[pd.datetime(2019,2,19)]
# Out:
# C:\Users\Dale Smith\AppData\Local\Temp\ipykernel_5428\737932930.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   df.loc[pd.datetime(2019,2,19)]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df.loc[pd.datetime(2019,2,19)]
#
# File D:\installFolder\Anaconda3\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File D:\installFolder\Anaconda3\lib\site-packages\pandas\core\indexing.py:1312, in _LocIndexer._getitem_axis(self, key, axis)
#    1310 # fall thru to straight lookup
#    1311 self._validate_key(key, axis)
# ...

# %%
df.iloc[10]
# Out:
# iso_code                                              AFG
# continent                                            Asia
# location                                      Afghanistan
# date                                  2020-01-13 00:00:00
# population                                       41128772
# total_cases                                           NaN
# new_cases                                               0
# new_cases_smoothed                                    0.0
# total_deaths                                          NaN
# new_deaths                                              0
# new_deaths_smoothed                                   0.0
# total_cases_per_million                               NaN
# new_cases_per_million                                   0
# new_cases_smoothed_per_million                        0.0
# total_deaths_per_million                              NaN
# new_deaths_per_million                                  0
# ...
